# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import string
import os
import re
plt.style.use('ggplot')
sns.set(rc={'figure.figsize':(10.7,4.27)})

# %%
# load data
# raw_data
file = '05_clean_data_OCT_19.csv'
data_directory = os.path.join( '..','data','raw_data/{}'.format(file))

# %%
df = pd.read_csv(data_directory)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 10 columns):
# name                 247 non-null object
# title                247 non-null object
# summary              247 non-null object
# year                 247 non-null int64
# transcript           247 non-null object
# link                 247 non-null object
# len_transcript       247 non-null int64
# dob                  247 non-null object
# sex                  247 non-null object
# age_when_recorded    247 non-null int64
# dtypes: int64(3), object(7)
# memory usage: 19.4+ KB

# %%
df.head()
# Out:
#            name                                       title  \
# 0  Nikki Glaser                                     Bangin’
# 1  Nikki Glaser                                     Perfect
# 2     Bill Burr                                 Paper Tiger
# 3     Bill Burr  Why Do I Do This   Testo Italiano Completo
# 4     Bill Burr                 I’M Sorry You Feel That Way
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 3  Va bene, grazie, grazie mille. Va bene, Gesù. ...  2008
# 4  [cheers and applause] All right, thank you! Th...  2014
#
#                                           transcript  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL\nThank you! ...
# 1  * * Ooh, ooh, ooh, ooh, ooh, ooh, ooh, ooh * *...
# 2  Recorded Live at the Royal Albert Hall, London...
# 3  Va bene, grazie, grazie mille. Va bene, Gesù. ...
# 4  [cheers and applause] All right, thank you! Th...
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 3  https://scrapsfromtheloft.com/2017/09/08/bill-...           45505
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
#
#           dob     sex  age_when_recorded
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 3  1968-06-10    Male                 40
# 4  1968-06-10    Male                 46

# %%
df.title.value_counts()[:10]
# Out:
# Live                                                    4
# Hot And Fluffy                                          1
# Messiah Complex                                         1
# Ehrenwort                                               1
# Annihilation                                            1
# You Magnificent Beast                                   1
# Buried Alive                                            1
# America Is The Greatest Country In The United States    1
# Tries For The First Time                                1
# Elephant In The Room                                    1
# Name: title, dtype: int64

# %% [markdown]
# ## get lang

# %%
df[df.title.str.contains('Italiano')]
# Out:
#              name                                           title  \
# 3       Bill Burr      Why Do I Do This   Testo Italiano Completo
# 42  George Carlin   Jamming In New York   Testo Italiano Completo
# 43  George Carlin  You Are All Diseased   Testo Italiano Completo
# 44  George Carlin      It’S Bad For Ya!   Testo Italiano Completo
#
#                                               summary  year  \
# 3   Va bene, grazie, grazie mille. Va bene, Gesù. ...  2008
# 42  Ciao, grazie. Grazie. Grazie. Grazie molte. Gr...  1992
# 43  Siete gentili, grazie! Grazie mille, lo apprez...  1999
# 44  Grazie, grazie, grazie! Mi piacerebbe iniziare...  2008
#
#                                            transcript  \
# 3   Va bene, grazie, grazie mille. Va bene, Gesù. ...
# 42  Ciao, grazie. Grazie. Grazie. Grazie molte. Gr...
# 43  Siete gentili, grazie! Grazie mille, lo apprez...
# 44  Grazie, grazie, grazie! Mi piacerebbe iniziare...
#
#                                                  link  len_transcript  \
# 3   https://scrapsfromtheloft.com/2017/09/08/bill-...           45505
# 42  https://scrapsfromtheloft.com/2017/04/12/georg...           48594
# 43  https://scrapsfromtheloft.com/2017/04/12/georg...           55839
# 44  https://scrapsfromtheloft.com/2017/04/12/georg...           56818
#
#            dob   sex  age_when_recorded
# 3   1968-06-10  Male                 40
# 42  1937-05-12  Male                 55
# 43  1937-05-12  Male                 62
# 44  1937-05-12  Male                 71

# %%
df.drop([3,42,43,44],inplace=True)

# %%
df[df.title.str.contains('Italiano')]
# Out:
# Empty DataFrame
# Columns: [name, title, summary, year, transcript, link, len_transcript, dob, sex, age_when_recorded]
# Index: []

# %%
df.head()
# Out:
#            name                        title  \
# 0  Nikki Glaser                      Bangin’
# 1  Nikki Glaser                      Perfect
# 2     Bill Burr                  Paper Tiger
# 4     Bill Burr  I’M Sorry You Feel That Way
# 5     Bill Burr  You People Are All The Same
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 4  [cheers and applause] All right, thank you! Th...  2014
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...  2012
#
#                                           transcript  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL\nThank you! ...
# 1  * * Ooh, ooh, ooh, ooh, ooh, ooh, ooh, ooh * *...
# 2  Recorded Live at the Royal Albert Hall, London...
# 4  [cheers and applause] All right, thank you! Th...
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
# 5  https://scrapsfromtheloft.com/2017/05/24/bill-...           65375
#
#           dob     sex  age_when_recorded
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 4  1968-06-10    Male                 46
# 5  1968-06-10    Male                 44

# %%
len(df)
# Out:
# 243

# %%
df.head()
# Out:
#            name                        title  \
# 0  Nikki Glaser                      Bangin’
# 1  Nikki Glaser                      Perfect
# 2     Bill Burr                  Paper Tiger
# 4     Bill Burr  I’M Sorry You Feel That Way
# 5     Bill Burr  You People Are All The Same
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 4  [cheers and applause] All right, thank you! Th...  2014
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...  2012
#
#                                           transcript  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL\nThank you! ...
# 1  * * Ooh, ooh, ooh, ooh, ooh, ooh, ooh, ooh * *...
# 2  Recorded Live at the Royal Albert Hall, London...
# 4  [cheers and applause] All right, thank you! Th...
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
# 5  https://scrapsfromtheloft.com/2017/05/24/bill-...           65375
#
#           dob     sex  age_when_recorded
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 4  1968-06-10    Male                 46
# 5  1968-06-10    Male                 44

# %%
df.name.value_counts()
# Out:
# George Carlin           13
# Dave Chappelle           9
# Louis C.K.               7
# Jim Jefferies            6
# Chris Rock               5
# Bill Burr                5
# Gabriel Iglesias         4
# Jimmy Carr               4
# Iliza Shlesinger         4
# Richard Pryor            4
# Eddie Izzard             4
# Kevin Hart               4
# Ricky Gervais            4
# Amy Schumer              4
# Sebastian Maniscalco     3
# Aziz Ansari              3
# Trevor Noah              3
# Bill Hicks               3
# Craig Ferguson           3
# Bill Maher               3
# John Mulaney             3
# Sarah Silverman          3
# Doug Stanhope            3
# Tom Segura               3
# Daniel Tosh              3
# Anthony Jeselnik         3
# Whitney Cummings         3
# Frankie Boyle            3
# Jo Koy                   2
# D.L. Hughley             2
#                         ..
# Jen Kirkman              1
# Maria Bamford            1
# Patrice O'Neal           1
# Hannah Gadsby            1
# Marc Maron               1
# Gina Yashere             1
# Pete Holmes              1
# John Leguizamo           1
# Jack Whitehall           1
# Enissa Amani             1
# Paul Mooney              1
# Fred Armisen             1
# Lewis Black              1
# Robin Williams           1
# Michelle Wolf            1
# Mike Epps                1
# Christina Pazsitzky      1
# Adel Karam               1
# Cristela Alonzo          1
# Kevin James              1
# Hasan Minhaj             1
# Rory Scovel              1
# Fahim Anwar              1
# Roy Wood Jr.             1
# Mo Amer                  1
# Erik Griffin             1
# Adam Sandler             1
# Bridget Everett          1
# Deray Davis              1
# Colin Quinn              1
# Name: name, Length: 128, dtype: int64

# %%
df.sex.value_counts()
# Out:
# Male      221
# Female     22
# Name: sex, dtype: int64

# %%
df.head()
# Out:
#            name                        title  \
# 0  Nikki Glaser                      Bangin’
# 1  Nikki Glaser                      Perfect
# 2     Bill Burr                  Paper Tiger
# 4     Bill Burr  I’M Sorry You Feel That Way
# 5     Bill Burr  You People Are All The Same
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 4  [cheers and applause] All right, thank you! Th...  2014
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...  2012
#
#                                           transcript  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL\nThank you! ...
# 1  * * Ooh, ooh, ooh, ooh, ooh, ooh, ooh, ooh * *...
# 2  Recorded Live at the Royal Albert Hall, London...
# 4  [cheers and applause] All right, thank you! Th...
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
# 5  https://scrapsfromtheloft.com/2017/05/24/bill-...           65375
#
#           dob     sex  age_when_recorded
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 4  1968-06-10    Male                 46
# 5  1968-06-10    Male                 44

# %% [markdown]
# ## Clen Text

# %%
def clean_text(data):
    #print(type(data))
    text = data.lower()
    text = re.sub('\[.*?\]', '', text)  # remove brackets & text inside
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)  # remove punctuations
    text = re.sub('\w*\d\w*', '', text)  # remove digits surounded by words
    text = re.sub('[‘’“”…]', '', text)  # remove quotes & elipses
    text = re.sub('\n', ' ', text)  # remove new line
    text = re.sub('\t', ' ', text)  # remove new line
    #text = re.sub(string.whitespace, '', text)  # remove \n\t..
    return text

# %%
df['clean_text'] = df.transcript.apply(clean_text)

# %%
df.head()
# Out:
#            name                        title  \
# 0  Nikki Glaser                      Bangin’
# 1  Nikki Glaser                      Perfect
# 2     Bill Burr                  Paper Tiger
# 4     Bill Burr  I’M Sorry You Feel That Way
# 5     Bill Burr  You People Are All The Same
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 4  [cheers and applause] All right, thank you! Th...  2014
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...  2012
#
#                                           transcript  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL\nThank you! ...
# 1  * * Ooh, ooh, ooh, ooh, ooh, ooh, ooh, ooh * *...
# 2  Recorded Live at the Royal Albert Hall, London...
# 4  [cheers and applause] All right, thank you! Th...
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
# 5  https://scrapsfromtheloft.com/2017/05/24/bill-...           65375
#
#           dob     sex  age_when_recorded  \
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 4  1968-06-10    Male                 46
# 5  1968-06-10    Male                 44
#
#                                           clean_text
# 0  a netflix original comedy special thank you th...
# 1    ooh ooh ooh ooh ooh ooh ooh ooh   ooh ooh oo...
# 2  recorded live at the royal albert hall london ...
# 4   all right thank you thank you very much thank...
# 5   ladies and gentlemen bill burr  all right tha...

# %%
# drop transcript
df.drop(['transcript'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            name                        title  \
# 0  Nikki Glaser                      Bangin’
# 1  Nikki Glaser                      Perfect
# 2     Bill Burr                  Paper Tiger
# 4     Bill Burr  I’M Sorry You Feel That Way
# 5     Bill Burr  You People Are All The Same
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 4  [cheers and applause] All right, thank you! Th...  2014
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...  2012
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
# 5  https://scrapsfromtheloft.com/2017/05/24/bill-...           65375
#
#           dob     sex  age_when_recorded  \
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 4  1968-06-10    Male                 46
# 5  1968-06-10    Male                 44
#
#                                           clean_text
# 0  a netflix original comedy special thank you th...
# 1    ooh ooh ooh ooh ooh ooh ooh ooh   ooh ooh oo...
# 2  recorded live at the royal albert hall london ...
# 4   all right thank you thank you very much thank...
# 5   ladies and gentlemen bill burr  all right tha...

# %%
len(df)
# Out:
# 243

# %%
len(df.name.unique())
# Out:
# 128

# %% [markdown]
# ## Saave

# %%
df.head()
# Out:
#            name                        title  \
# 0  Nikki Glaser                      Bangin’
# 1  Nikki Glaser                      Perfect
# 2     Bill Burr                  Paper Tiger
# 4     Bill Burr  I’M Sorry You Feel That Way
# 5     Bill Burr  You People Are All The Same
#
#                                              summary  year  \
# 0  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...  2019
# 1  Nikki Glaser brings her sharp wit to her first...  2016
# 2  Only a few weeks after Dave Chappelle's "Stick...  2019
# 4  [cheers and applause] All right, thank you! Th...  2014
# 5  [Crowd chatter] Ladies and gentlemen: Bill Bur...  2012
#
#                                                 link  len_transcript  \
# 0  https://scrapsfromtheloft.com/2019/10/04/nikki...           53937
# 1  https://scrapsfromtheloft.com/2018/05/16/nikki...           59586
# 2  https://scrapsfromtheloft.com/2019/09/10/bill-...           60486
# 4  https://scrapsfromtheloft.com/2017/05/24/bill-...           64608
# 5  https://scrapsfromtheloft.com/2017/05/24/bill-...           65375
#
#           dob     sex  age_when_recorded  \
# 0  1984-01-01  Female                 35
# 1  1984-01-01  Female                 32
# 2  1968-06-10    Male                 51
# 4  1968-06-10    Male                 46
# 5  1968-06-10    Male                 44
#
#                                           clean_text
# 0  a netflix original comedy special thank you th...
# 1    ooh ooh ooh ooh ooh ooh ooh ooh   ooh ooh oo...
# 2  recorded live at the royal albert hall london ...
# 4   all right thank you thank you very much thank...
# 5   ladies and gentlemen bill burr  all right tha...

# %%
# raw_data
file = '06_clean_data_OCT_19.csv'
data_directory = os.path.join( '..','data','raw_data/{}'.format(file))

# %%
ls
# Out:
# 01_get_list.ipynb*         04_clean_data.ipynb*     06_English_only.ipynb
# 02_get_transcripts.ipynb*  04_english_only.ipynb    George_Carlin.ipynb*
# 03_merge_data.ipynb*       05_DOB_Wiki_Data.ipynb*  Untitled.ipynb*
